# %%
# !pip install pydot
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
def generateGraphPlot(graphFilename, source = None):
    G = nx.DiGraph()
    
    graphTxt = open(graphFilename, "r")

    rowNo = 0
    line = graphTxt.readline()
    while (line != ''):
        row = line.split("\n")[0].split(" ")

        for i, weight in enumerate(row):
            if weight != "0":

                u = rowNo
                v = i

                G.add_edge(u, v, weight = float(weight))


        line = graphTxt.readline()

        rowNo+= 1

    pos = nx.spring_layout(G)

    color_map = []

    if (source == None):
        for node in G:
            color_map.append('blue')
    else:

        for node in G:
            if node == source:
                color_map.append('red')
            else: 
                color_map.append('blue')
            
    labels = nx.get_edge_attributes(G, 'weight')
    labels = {k: f'{v:.2f}' for k, v in labels.items()}

    nx.draw(G, pos, with_labels=True, node_color=color_map)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

    plt.show()

# %%
generateGraphPlot("text1.txt")

# %%
generateGraphPlot("disjktra1.txt", 0)

# %%
generateGraphPlot("a_star.txt")

# %% [markdown]
# # Grafo 1: 6 nodos 8 aristas

# %%
generateGraphPlot("grafo1.txt")
generateGraphPlot("grafo1dijkstra.txt", 1)

# %% [markdown]
# # Grafo 2: 10 nodos 25 aristas

# %%
generateGraphPlot("grafo2.txt")
generateGraphPlot("grafo2dijkstra.txt", 4)

# %% [markdown]
# # Grafo 3: 7 nodos 12 aristas

# %%
generateGraphPlot("grafo3.txt")
generateGraphPlot("grafo3dijkstra.txt", 0)

# %% [markdown]
# # Grafo 4: 11 nodos 20 aristas

# %%
generateGraphPlot("grafo4.txt")
generateGraphPlot("grafo4dijkstra.txt", 8)

# %% [markdown]
# # Grafo 5: 4 nodos 5 aristas

# %%
generateGraphPlot("grafo5.txt")
generateGraphPlot("grafo5dijkstra.txt", 3)
